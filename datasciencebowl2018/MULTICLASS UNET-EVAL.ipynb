# %%
from utility.utils import *
from dataset.dataset import *
from dataset.transform import *
from model.loss import *
from model.unet import UNet256_3x3
from training.classifier import NucleiClassifier
from model.eval import *
from dataset.submission import *

import torch
from torch.autograd import Variable as V
import torch.nn.functional as F
import torch.optim as optim

from skimage.morphology import label
from collections import OrderedDict
import matplotlib.pyplot as plt
import cv2
import shutil
import os

# %% [markdown]
# ### Create Random (Stratified) Train and Validation Set - RUN AS NEEDED

# %%
classes = pd.read_csv('classes.csv')
train_dirs, valid_dirs = get_stratified_valid_dirs(classes, seed=17)

# %%
main_path = '../data/ds_bowl_2018/'
full_path = '../data/ds_bowl_2018/full_data/'

# %%
create_validation_dirs(main_path, full_path, None, train_dirs, valid_dirs)
# Out:
# Copied 606 training and 64 validation data

# %%
# test distribution
classes[~classes.is_train].groupby(['foreground', 'background']).count()
# Out:
#                        filename  is_train
# foreground background
# purple     purple             1         1
#            white              3         3
#            yellow             8         8
# white      black             53        53

# %%
# distributions seem similar to test
classes[classes.filename.isin([f + '.png' for f in valid_dirs])].groupby(['foreground', 'background']).count()
# Out:
#                        filename  is_train
# foreground background
# purple     purple             2         2
#            white              4         4
# white      black             58        58

# %% [markdown]
# ### Training Data Prep
#
# In multiclass UNET we will not be outputing a single channel like we did for binary classification background or mask but rather this time we will have a 3 channel output. Each channel will correspond to probability distributions for background, mask and overlap. We will be using multiclass BCE Loss.
#
# Output Channels:
#
# - Background
# - Foreground
# - Overlap
#
#
# If there are 3 unique pixel intensities
#
# - 30 : Background
# - 110 : Nuclei
# - 215 : Overlap Boundary
#
# If there are 2 unique pixel intensities
#
# - 30 : Background
# - 215 : Nuclei
#
# w_background, w_nuclei, w_overlap = (1.1551767249306626, 7.544967099214484, 557.753645718466)

# %%
train_path = '../data/ds_bowl_2018/train/'
valid_path = '../data/ds_bowl_2018/valid/'
dummy_path = '../data/ds_bowl_2018/dummy/'

# %%
train_dirs = list_directory(train_path)
valid_dirs = list_directory(valid_path)
dummy_dirs = list_directory(dummy_path)

# %%
list_directory(train_dirs[0])
# Out:
# ['../data/ds_bowl_2018/train/58406ed8ef944831c413c3424dc2b07e59aef13eb1ff16acbb3402b38b5de0bd/images/',
#  '../data/ds_bowl_2018/train/58406ed8ef944831c413c3424dc2b07e59aef13eb1ff16acbb3402b38b5de0bd/one_mask.png/',
#  '../data/ds_bowl_2018/train/58406ed8ef944831c413c3424dc2b07e59aef13eb1ff16acbb3402b38b5de0bd/mclass_one_mask.png/',
#  '../data/ds_bowl_2018/train/58406ed8ef944831c413c3424dc2b07e59aef13eb1ff16acbb3402b38b5de0bd/masks/']

# %%
len(train_dirs), len(valid_dirs), len(dummy_dirs)
# Out:
# (606, 64, 2)

# %%
def get_3d_mask(mask):
    if len(np.unique(mask)) == 2:
        back_channel = (mask == 30)*1 # background
        nuclei_channel = (mask == 215)*1 # nuclei
        overlap_channel = np.zeros_like(mask) # overlap - missing so all 0s
    else:
        back_channel = (mask == 30)*1 # background
        nuclei_channel = (mask == 110)*1 # nuclei
        overlap_channel = (mask == 215)*1 # overlap
    # stack depth-wise
    multiclass_mask = np.dstack([back_channel, nuclei_channel, overlap_channel])
    return multiclass_mask

# %%
def train_augment(image, mask, index, sz = 256):           
    # get 3d mask
    mask3d = get_3d_mask(mask).astype(np.uint8) 
    # resize image, mask for Unet256
    image = fix_resize_transform(image, sz, sz)
    mask3d = fix_resize_transform(mask3d, sz, sz) 
    # get dimensions right for pytorch
    image = (image.transpose((2,0,1))) / 255 
    mask3d = (mask3d.transpose((2,0,1)))
    return image.astype(np.float64), mask3d.astype(np.float64), index

def valid_augment(image, mask, index, sz = 256):        
    # get 3d mask
    mask3d = get_3d_mask(mask).astype(np.uint8) 
    # resize image, mask for Unet256
    image = fix_resize_transform(image, sz, sz)
    mask3d = fix_resize_transform(mask3d, sz, sz) 
    # get dimensions right for pytorch
    image = (image.transpose((2,0,1))) / 255 
    mask3d = (mask3d.transpose((2,0,1)))
    return image.astype(np.float64), mask3d.astype(np.float64), index


def test_augment(image, mask, index, sz = 256):
    # resize image for Unet256
    image = fix_resize_transform(image, sz, sz)
    # normalize pixel intensities
    image = (image.transpose((2,0,1))) / 255 
    return image.astype(np.float64), index

# %%
# # create dummyloader
dummy_ds = NucleiDataset('../data/ds_bowl_2018/dummy/', transform=train_augment, mode='train', mask_file='/mclass_one_mask.png')
dummy_dl = DataLoader(dummy_ds, batch_size=1, shuffle=False)
# create trainloader
trn_ds = NucleiDataset('../data/ds_bowl_2018/train/', transform=train_augment, mode='train', mask_file='/mclass_one_mask.png')
trn_dl = DataLoader(trn_ds, batch_size=16, shuffle=True)
# create validloader.png
val_ds = NucleiDataset('../data/ds_bowl_2018/valid/', transform=valid_augment, mode='valid', mask_file='/mclass_one_mask.png')
val_dl = DataLoader(val_ds, batch_size=16, shuffle=False)
# create testloader
test_ds = NucleiDataset('../data/ds_bowl_2018/test/', transform=test_augment, mode='test')
test_dl = DataLoader(test_ds, batch_size=1, shuffle=False)

# %%
class Weighted_BCELoss2d(nn.Module):
    """
    Weights for a single sample which is repeated along the batch
    Inputs:
        weight: weigth tensor for a single sample
    """
    def __init__(self, weight=None):
        super(Weighted_BCELoss2d, self).__init__()
        self.weight = weight
        
    def forward(self, logits, targets):
        # contruct bce loss
        batch_size = targets.size(0)
        weights = self.weight.repeat(batch_size)
        bce_loss = nn.BCELoss(weights)
        # calc loss
        probs        = F.softmax(logits, dim=1)
        probs_flat   = probs.view (-1)
        targets_flat = targets.view(-1)
        return bce_loss(probs_flat, targets_flat)

# %%
w_background, w_nuclei, w_overlap = (1.155, 7.544, 557.753)
weights = torch.cat([torch.ones(256*256)*w_background, 
                     torch.ones(256*256)*w_nuclei, torch.ones(256*256)*w_overlap]).double()

# %%
# training definition
net = UNet256_3x3(in_shape=(3, 256, 256), num_classes=3).double()
#optimizer = optim.Adam(net.parameters(), lr=0.1)
optimizer = optim.RMSprop(net.parameters(), lr=0.1)
# weighted BCELoss
crit = Weighted_BCELoss2d(weights)

# %%
# init classifier
classifier = NucleiClassifier(net, optimizer, crit=crit, metric=dice_coeff)

# %%
#classifier.restore_model('./models/mclass_20')

# %%
# train for 10 epochs
for i in range(30):
    classifier.train(train_loader=trn_dl, valid_loader=val_dl, optimizer=optimizer,crit=crit, epochs=10, threshold=0.5)
    print(f'saving at {(classifier.epoch_counter)}')
    classifier.save_model(f'./models/mclass_{classifier.epoch_counter}', None)
# Out:
# Epoch: 908
# Training : [0.3883],Validation : [3.8414]
# Epoch: 909
# Training : [0.3582],Validation : [3.9667]
# Epoch: 910
# Training : [0.3997],Validation : [4.0058]
# Epoch: 911
# Training : [0.3512],Validation : [4.0312]
# Epoch: 912
# Training : [0.4455],Validation : [3.6889]
# Epoch: 913
# Training : [0.3784],Validation : [4.0896]
# Epoch: 914
# Training : [0.3294],Validation : [4.3477]
# Epoch: 915
# Training : [0.3524],Validation : [3.8282]
# Epoch: 916
# Training : [0.3577],Validation : [3.684]
# Epoch: 917
# Training : [0.3664],Validation : [3.9708]
# saving at 917
# Epoch: 918
# Training : [0.3526],Validation : [4.7712]
# Epoch: 919
# Training : [0.4323],Validation : [3.5301]
# Epoch: 920
# Training : [0.3889],Validation : [3.8281]
# Epoch: 921
# Training : [0.3545],Validation : [3.9922]
# Epoch: 922
# Training : [0.3264],Validation : [4.2158]
# Epoch: 923
# Training : [0.409],Validation : [3.3195]
# Epoch: 924
# Training : [0.3986],Validation : [4.0436]
# Epoch: 925
# Training : [0.3343],Validation : [4.1039]
# Epoch: 926
# Training : [0.3651],Validation : [3.5455]
# Epoch: 927
# Training : [0.3501],Validation : [4.3803]
# saving at 927
# Epoch: 928
# Training : [0.341],Validation : [4.1113]
# Epoch: 929
# Training : [0.3596],Validation : [4.3312]
# Epoch: 930
# Training : [0.5793],Validation : [3.4013]
# Epoch: 931
# Training : [0.3609],Validation : [3.8342]
# Epoch: 932
# Training : [0.3251],Validation : [4.5293]
# Epoch: 933
# Training : [0.322],Validation : [4.2838]
# Epoch: 934
# Training : [0.325],Validation : [4.3761]
# Epoch: 935
# Training : [0.3366],Validation : [3.5532]
# Epoch: 936
# Training : [0.3726],Validation : [4.2429]
# Epoch: 937
# Training : [0.3551],Validation : [3.9401]
# saving at 937
# Epoch: 938
# Training : [0.3436],Validation : [3.7873]
# Epoch: 939
# Training : [0.372],Validation : [4.0995]
# Epoch: 940
# Training : [0.3225],Validation : [4.2824]
# Epoch: 941
# Training : [0.4425],Validation : [3.4744]
# Epoch: 942
# Training : [0.3808],Validation : [3.7693]
# Epoch: 943
# Training : [0.3523],Validation : [4.0]
# Epoch: 944
# Training : [0.3291],Validation : [4.2383]
# Epoch: 945
# Training : [0.391],Validation : [3.3592]
# Epoch: 946
# Training : [0.3422],Validation : [4.0426]
# Epoch: 947
# Training : [0.3463],Validation : [4.0061]
# saving at 947
# Epoch: 948
# Training : [0.3736],Validation : [3.7338]
# Epoch: 949
# Training : [0.3367],Validation : [4.0109]
# Epoch: 950
# Training : [0.3361],Validation : [4.2004]
# Epoch: 951
# Training : [0.3632],Validation : [3.9943]
# Epoch: 952
# Training : [0.3533],Validation : [3.9874]
# Epoch: 953
# Training : [0.3618],Validation : [3.8351]
# Epoch: 954
# Training : [0.3768],Validation : [3.891]
# Epoch: 955
# Training : [0.3354],Validation : [3.709]
# Epoch: 956
# Training : [0.3456],Validation : [4.1648]
# Epoch: 957
# Training : [0.3364],Validation : [4.1182]
# saving at 957
# Epoch: 958
# Training : [0.3445],Validation : [4.3939]
# Epoch: 959
# Training : [0.3798],Validation : [4.0111]
# Epoch: 960
# Training : [0.3772],Validation : [4.2363]
# Epoch: 961
# Training : [0.3317],Validation : [3.9892]
# Epoch: 962
# Training : [0.3414],Validation : [4.0964]
# Epoch: 963
# Training : [0.3395],Validation : [4.0256]
# Epoch: 964
# Training : [0.3503],Validation : [4.6394]
# Epoch: 965
# Training : [0.3734],Validation : [4.0853]
# Epoch: 966
# Training : [0.3427],Validation : [4.1131]
# Epoch: 967
# Training : [0.3331],Validation : [4.3475]
# saving at 967
# Epoch: 968
# Training : [0.4771],Validation : [3.5315]
# Epoch: 969
# Training : [0.3435],Validation : [4.1633]
# Epoch: 970
# Training : [0.3173],Validation : [4.2377]
# Epoch: 971
# Training : [0.3145],Validation : [4.1553]
# Epoch: 972
# Training : [0.3395],Validation : [4.4719]
# Epoch: 973
# Training : [0.3357],Validation : [4.1187]
# Epoch: 974
# Training : [0.3441],Validation : [4.3651]
# Epoch: 975
# Training : [0.367],Validation : [3.0678]
# Epoch: 976
# Training : [0.3532],Validation : [4.1195]
# Epoch: 977
# Training : [0.4868],Validation : [4.1095]
# saving at 977
# Epoch: 978
# Training : [0.3251],Validation : [4.6944]
# Epoch: 979
# Training : [0.3162],Validation : [4.5625]
# Epoch: 980
# Training : [0.3238],Validation : [4.1641]
# Epoch: 981
# Training : [0.3199],Validation : [4.1187]
# Epoch: 982
# Training : [0.4904],Validation : [4.1736]
# Epoch: 983
# Training : [0.3648],Validation : [3.9617]
# Epoch: 984
# Training : [0.3005],Validation : [4.3872]
# Epoch: 985
# Training : [0.3],Validation : [4.5728]
# Epoch: 986
# Training : [0.3188],Validation : [4.2536]
# Epoch: 987
# Training : [0.3329],Validation : [4.1526]
# saving at 987
# Epoch: 988
# Training : [0.3291],Validation : [4.6868]
# Epoch: 989
# Training : [0.3806],Validation : [4.1113]
# Epoch: 990
# Training : [0.3379],Validation : [4.3453]
# Epoch: 991
# Training : [0.3211],Validation : [4.1333]
# Epoch: 992
# Training : [0.3391],Validation : [4.0455]
# Epoch: 993
# Training : [0.3106],Validation : [3.4829]
# Epoch: 994
# Training : [0.3969],Validation : [4.0695]
# Epoch: 995
# Training : [0.3154],Validation : [4.3374]
# Epoch: 996
# Training : [0.3247],Validation : [4.345]
# Epoch: 997
# Training : [0.3422],Validation : [4.1729]
# saving at 997
# Epoch: 998
# Training : [0.4215],Validation : [4.0228]
# Epoch: 999
# Training : [0.3325],Validation : [4.6384]
# Epoch: 1000
# Training : [0.343],Validation : [4.2551]
# Epoch: 1001
# Training : [0.3311],Validation : [3.9958]
# Epoch: 1002
# Training : [0.3148],Validation : [3.8902]
# Epoch: 1003
# Training : [0.3095],Validation : [4.55]
# Epoch: 1004
# Training : [0.3935],Validation : [4.1915]
# Epoch: 1005
# Training : [0.3417],Validation : [4.0433]
# Epoch: 1006
# Training : [0.3691],Validation : [3.9969]
# Epoch: 1007
# Training : [0.3177],Validation : [4.1448]
# saving at 1007
# Epoch: 1008
# Training : [0.3301],Validation : [4.324]
# Epoch: 1009
# Training : [0.3064],Validation : [4.2012]
# Epoch: 1010
# Training : [0.4274],Validation : [3.9478]
# Epoch: 1011
# Training : [0.3221],Validation : [4.4904]
# Epoch: 1012
# Training : [0.3634],Validation : [4.3387]
# Epoch: 1013
# Training : [0.3047],Validation : [4.6004]
# Epoch: 1014
# Training : [0.3034],Validation : [4.3475]
# Epoch: 1015
# Training : [0.3377],Validation : [4.2805]
# Epoch: 1016
# Training : [0.3194],Validation : [4.3357]
# Epoch: 1017
# Training : [0.3275],Validation : [4.1072]
# saving at 1017
# Epoch: 1018
# Training : [0.3569],Validation : [4.1712]
# Epoch: 1019
# Training : [0.3335],Validation : [4.0415]
# Epoch: 1020
# Training : [0.3279],Validation : [4.2062]
# Epoch: 1021
# Training : [0.3432],Validation : [4.1957]
# Epoch: 1022
# Training : [0.3534],Validation : [4.5721]
# Epoch: 1023
# Training : [0.3406],Validation : [4.0027]
# Epoch: 1024
# Training : [0.3198],Validation : [4.373]
# Epoch: 1025
# Training : [0.3009],Validation : [4.5569]
# Epoch: 1026
# Training : [0.3552],Validation : [3.92]
# Epoch: 1027
# Training : [0.3427],Validation : [4.249]
# saving at 1027
# Epoch: 1028
# Training : [0.3098],Validation : [4.3926]
# Epoch: 1029
# Training : [0.3557],Validation : [4.7045]
# Epoch: 1030
# Training : [0.3263],Validation : [4.4158]
# Epoch: 1031
# Training : [0.329],Validation : [3.7153]
# Epoch: 1032
# Training : [0.3228],Validation : [3.9942]
# Epoch: 1033
# Training : [0.3379],Validation : [4.1197]
# Epoch: 1034
# Training : [0.3419],Validation : [4.1472]
# Epoch: 1035
# Training : [0.317],Validation : [4.3418]
# Epoch: 1036
# Training : [0.3837],Validation : [4.287]

# %% [markdown]
# ### Evaluate by Eye

# %%
def to_np(tensor):
    if type(tensor) == V:
        return tensor.data.cpu().numpy()
    else:
        return tensor.cpu().numpy()

# %%
def show_side_to_side(im1, im2, figsize=(13, 13)):
    plt.figure(figsize=figsize)
    plt.subplot(1,2,1)
    plt.imshow(im1)
    plt.subplot(1,2,2)
    plt.imshow(im2)
    plt.show()
    plt.close()

# %%
val_ds = NucleiDataset('../data/ds_bowl_2018/valid/', transform=valid_augment,
                       mode='valid', mask_file='/mclass_one_mask.png')
val_dl = DataLoader(val_ds, batch_size=1, shuffle=False)

# %%
it = iter(val_dl)

# %%
img, mask, id_ = next(it)

# %%
img_np, mask_np = to_np(img), to_np(mask)

# %%
classifier.restore_model('./models/mclass_404', 1)
net = classifier.net.eval()
out = net(V(img))
prob, idx = torch.max(out, 1)
preds1 = to_np(idx)[0] # predictions from less complex model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-98fc6cd17e99> in <module>()
# ----> 1 classifier.restore_model('./models/mclass_404', 1)
#       2 net = classifier.net.eval()
#       3 out = net(V(img))
#       4 prob, idx = torch.max(out, 1)
#       5 preds1 = to_np(idx)[0] # predictions from less complex model
#
# ~/Desktop/GITHUB/deeplearning/datasciencebowl2018/training/classifier.py in restore_model(self, path, gpu)
#     134         """
#     135         self.net.cpu()
# --> 136         state = torch.load(path)
#     137         self.net.load_state_dict(state['state_dict'])
#     138         self.optimizer.load_state_dict(state['optimizer'])
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     257             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     258         new_fd = True
# --> 259         f = open(f, 'rb')
#     260     try:
#     261         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: './models/mclass_404'

# %%
classifier.restore_model('./models/mclass_404')
net = classifier.net.eval()
out = net(V(img).cuda())
prob, idx = torch.max(out, 1)
preds1 = to_np(idx)[0] # predictions from less complex model

classifier.restore_model('./models/mclass_907')
net = classifier.net.eval()
out = net(V(img).cuda())
prob, idx = torch.max(out, 1)
preds2 = to_np(idx)[0] # predictions from more complex model


show_side_to_side(preds1, preds2)

# %%
show_with_sz(mask[0,1], 7)

# %%
show_with_sz(img_np[0, 0], 7)

# %% [markdown]
# ### Predictions

# %%
from skimage.morphology import label

# %%
# load model and predict
classifier.restore_model('./models/mclass_907')
preds = classifier.predict(test_dl)

# %%
preds_masks = []
for i in range(len(preds)):
    preds_idx = np.argmax(preds[i], 1) # get argmax
    preds_mask = (preds_idx == 1)[0] # get masks
    preds_masks.append(preds_mask.astype(np.uint8))

# %%
# get correct sizes
test_sz = []
for fpath in test_ds.image_dirs:
    fname = fpath + 'images/' + fpath.split('/')[-2] + '.png'
    h, w = cv2.imread(fname, cv2.IMREAD_GRAYSCALE).shape
    test_sz.append((w, h))

# %%
# resize preds_masks
resized_preds = [cv2.resize(preds_mask, test_sz[i]) for i, preds_mask in enumerate(preds_masks)]

# %% [markdown]
# ### Post Process

# %%
i = 0

# %%
img_path = test_ds.image_dirs[i]
fname = img_path + 'images/' + img_path.split('/')[-2] + '.png'

# %%
show_with_sz(read3d(fname))

# %%
from scipy.ndimage.morphology import binary_fill_holes

# %%
show_with_sz(resized_preds[i])

# %%
filled_resized_pred = binary_fill_holes(resized_preds[i])
show_with_sz(filled_resized_pred)

# %%
#from scipy.signal import convolve2d
#kernel = np.ones((2,2))
#out = convolve2d(filled_resized_pred, kernel, mode='same')
#show_with_sz(label(out > 2))

# %% [markdown]
# # Create Submission

# %%
filled_resized_preds = [binary_fill_holes(pred).astype(np.uint8) for pred in resized_preds]

# %%
def predict_and_submit(preds, test_ds):    
    new_test_ids = []
    rles = []
    for n, id_ in enumerate(test_ds.image_dirs):
        id_ = id_.split('/')[-2]
        rle = list(prob_to_rles(preds[n]))
        rles.extend(rle)
        new_test_ids.extend([id_] * len(rle))
    
    sub = pd.DataFrame()
    sub['ImageId'] = new_test_ids
    sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
    return sub

# %%
sub_df = predict_and_submit(filled_resized_preds, test_ds)
sub_df.shape
# Out:
# (3517, 2)

# %%
for i, pred in enumerate(filled_resized_preds):
    print(i)
    img = test_ds.__getitem__(i)[0].transpose((1,2,0))
    show_side_to_side(img, pred)

# %% [raw]
# from collections import Counter
#
# def rm_large_connected(img, thresh):
#     """Remove large connected components"""
#     img = label(img)
#     h, w = img.shape
#     counts = Counter(img.flatten())
#     rm_labels = [k for k in counts if counts[k] > h*w*thresh and k != 0]
#     for lbl in rm_labels:
#         img[img == lbl] = 0
#     img = (img > 0)*1
#     return img
#
# filled_resized_small = [rm_large_connected(img, 0.03)
#                          for img
#                          in filled_resized_preds]
#
# for i, pred in enumerate(filled_resized_small):
#     print(i)
#     img = test_ds.__getitem__(i)[0].transpose((1,2,0))
#     show_side_to_side(img, pred)
#
# sub_df = predict_and_submit(filled_resized_small, test_ds)
# sub_df.shape

# %%
sub_df.to_csv('./mclass_unet_basic.csv', index=False)
